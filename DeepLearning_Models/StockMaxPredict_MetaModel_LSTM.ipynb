# %% [markdown]
# ### **Compañía Meta**

# %%
# Importación de librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop, SGD, Adagrad, Nadam, Ftrl
import tensorflow as tf
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Carga de datos
df=pd.read_csv("https://raw.githubusercontent.com/JersonGB22/DataScience_IBM_StockPredictionLSTM_Project/main/DataStorage/datasets_company_etl.csv")
df["Date"]=pd.to_datetime(df.Date)
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2013-01-02   19.779285   19.821428   19.343929   19.608213   16.791185
# 1     2013-01-02   27.250000   27.730000   27.150000   27.620001   22.620338
# 2     2013-01-02    2.333333    2.363333    2.314000    2.357333    2.357333
# 3     2013-01-02   12.804000   12.905000   12.663000   12.865500   12.865500
# 4     2013-01-02   17.918339   18.107130   17.846855   18.013729   18.013729
# ...          ...         ...         ...         ...         ...         ...
# 27379 2023-09-18  298.190002  303.600006  297.799988  302.549988  302.549988
# 27380 2023-09-18  327.799988  330.399994  326.359985  329.059998  329.059998
# 27381 2023-09-18  140.479996  141.750000  139.220001  139.979996  139.979996
# 27382 2023-09-18  271.160004  271.440002  263.760010  265.279999  265.279999
# 27383 2023-09-18  137.630005  139.929993  137.630005  138.960007  138.960007
#
#           Volume id_company
# 0      560518000       AAPL
# 1       52899300       MSFT
# 2       17922000       TSLA
# 3       65420000       AMZN
# 4      102033017       GOOG
# ...          ...        ...
# 27379   14234200       META
# 27380   16834200       MSFT
# 27381   42823500       AMZN
# 27382  101543300       TSLA
# 27383   16233600       GOOG
#
# [27384 rows x 8 columns]

# %%
# Función unificada
def feature_creation(df, company, input_len, output_len):

  def variable_selection(df, company):
    df2=df.copy()
    df2=df2[df2.id_company==company]
    df2=df2.iloc[:, :5].reset_index(drop=True)
    return df2

  df1=variable_selection(df, company)

  def data_scaling(set_data):
    set_data2=set_data.copy()
    cols=set_data2.columns[1:]
    list_mms=[MinMaxScaler() for c in set_data2.columns]
    for i, c in enumerate(cols):
      set_data2[c]=list_mms[i].fit_transform(set_data2[[c]])
    return set_data2, list_mms[1]

  df2, mms = data_scaling(df1)

  def train_test_split(set_data):
    set_train=set_data[set_data.Date<="2021-12-31"]
    set_test=set_data[set_data.Date>"2021-12-31"]
    return set_train.iloc[:, 1:].values, set_test.iloc[:, 1:].values

  set_train, set_test = train_test_split(df2)

  def find_xy(array, input_len, output_len):
    row, col = array.shape[0], array.shape[1]
    x, y = [], []
    for i in range(row-input_len-output_len+1):
      x.append(array[i:i+input_len])
      y.append(array[i+input_len:i+input_len+output_len, 1].reshape(output_len, 1))
    x=np.array(x)
    y=np.array(y)
    return x, y

  x_train, y_train = find_xy(set_train, input_len, output_len)
  x_test, y_test = find_xy(set_test, input_len, output_len)

  return x_train, y_train, x_test, y_test, mms

# %% [markdown]
# **OBSERVACIÓN:** En nuestro modelo de series de tiempo ``multivariado multi-step`` utilizando redes LSTM, hemos seleccionado bloques consecutivos de 90 días para el tamaño de entrada, para permitir una memoria más extensa en comparación con bloques de 30 días. También se evaluó con bloques de 60 días, pero se observó un aumento en la función de pérdida ``loss``. Además, he configurado el tamaño de salida en 7 días para que el modelo pueda realizar predicciones de las acciones máximas para una semana completa.

# %%
# Hallando los sets de entrenamiento y validación
input_len=90
output_len=7
x_train, y_train, x_test, y_test, mms = feature_creation(df, "META", input_len, output_len)

# %% [markdown]
# #### **Creación, Compilación y Entrenamiento del modelo**
# - Entradas: arreglos *x* (batches x input-length  x features = batches x 90 x 4)
#
# - Salidas: arreglos *y* (batches x output-length x features = batches x 7 x 1)
#
# - El modelo se compone de una capa LSTM con 256 unidades. Se realizaron experimentos con la cantidad de capas LSTM y el número de unidades, pero se observó un aumento en la función de pérdida. Además, se incorporó una capa Dropout para prevenir el overfitting con una tasa del 20%. La capa de salida utiliza una función de activación `linear`, que es la elección adecuada para problemas de series de tiempo, dado que otras funciones no son recomendables en este contexto.
#
# - En la fase de compilación del modelo, se optó por emplear el optimizador ``Adam`` con un valor de ``learning_rate establecido`` en 0.001. Se realizaron pruebas con diversos optimizadores, incluyendo ``RMSprop`` y `SGD`, pero se observó un incremento en la función de pérdida. Asimismo, se llevaron a cabo experimentos con distintos valores de learning_rate para Adam, y se encontró que el que logró una reducción más significativa en el error fue el de 0.001. Como función de pérdida se seleccionó el RMSE (Root Mean Square Error):
#
#     $RMSE = \sqrt{\frac{\sum_i (y_i-\hat{y_i})^2}{N}}$
#
#     donde:
# - $y$: precio real más alto alcanzado durante el día por la compañía Meta
# - $\hat{y}$: precio predicho más alto alcanzado durante el día por la compañía Meta
# - $N$: cantidad de predicciones
#
# - Durante el proceso de entrenamiento, se eligió un batch size de 256, y se determinó mediante experimentación que el número óptimo de épocas para lograr la reducción más efectiva de la función de error fue de 160.

# %%
# Ajuste de parámetros para reproducibilidad del entrenamiento
tf.random.set_seed(123)
tf.config.experimental.enable_op_determinism()
np.random.seed(123)

# %%
# Creación del modelo
model=Sequential()
model.add(LSTM(256, input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(output_len, activation="linear"))

# Creación de la función de pérdida (Raíz del error cuadrático medio)
def RMSE(y_true, y_pred):
  rmse=tf.math.sqrt(tf.math.reduce_mean(tf.square(y_true-y_pred)))
  return rmse

# Creación del optimizador
optimizer=Adam(learning_rate=0.001)

# Compilación
model.compile(optimizer=optimizer, loss=RMSE)

# Entrenamiento
history=model.fit(x_train, y_train, batch_size=256, epochs=160, validation_data=(x_test, y_test), verbose=1)
# Out:
# Epoch 1/160
# 13/13 [==============================] - 8s 67ms/step - loss: 0.1668 - val_loss: 0.0549
# Epoch 2/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0588 - val_loss: 0.0411
# Epoch 3/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0446 - val_loss: 0.0323
# Epoch 4/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0409 - val_loss: 0.0319
# Epoch 5/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0381 - val_loss: 0.0314
# Epoch 6/160
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0375 - val_loss: 0.0329
# Epoch 7/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0360 - val_loss: 0.0314
# Epoch 8/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0359 - val_loss: 0.0315
# Epoch 9/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0347 - val_loss: 0.0311
# Epoch 10/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0331 - val_loss: 0.0323
# Epoch 11/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0326 - val_loss: 0.0307
# Epoch 12/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0327 - val_loss: 0.0324
# Epoch 13/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0323 - val_loss: 0.0310
# Epoch 14/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0313 - val_loss: 0.0321
# Epoch 15/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0313 - val_loss: 0.0300
# Epoch 16/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0305 - val_loss: 0.0312
# Epoch 17/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0308 - val_loss: 0.0312
# Epoch 18/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0293 - val_loss: 0.0299
# Epoch 19/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0283 - val_loss: 0.0343
# Epoch 20/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0295 - val_loss: 0.0302
# Epoch 21/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0293 - val_loss: 0.0298
# Epoch 22/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0284 - val_loss: 0.0304
# Epoch 23/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0282 - val_loss: 0.0340
# Epoch 24/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0281 - val_loss: 0.0319
# Epoch 25/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0280 - val_loss: 0.0308
# Epoch 26/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0266 - val_loss: 0.0295
# Epoch 27/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0264 - val_loss: 0.0328
# Epoch 28/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0279 - val_loss: 0.0306
# Epoch 29/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0273 - val_loss: 0.0291
# Epoch 30/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0262 - val_loss: 0.0291
# Epoch 31/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0254 - val_loss: 0.0288
# Epoch 32/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0261 - val_loss: 0.0289
# Epoch 33/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0261 - val_loss: 0.0290
# Epoch 34/160
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0255 - val_loss: 0.0292
# Epoch 35/160
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0254 - val_loss: 0.0319
# Epoch 36/160
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0251 - val_loss: 0.0290
# Epoch 37/160
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0249 - val_loss: 0.0289
# Epoch 38/160
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0249 - val_loss: 0.0285
# Epoch 39/160
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0249 - val_loss: 0.0305
# Epoch 40/160
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0246 - val_loss: 0.0288
# Epoch 41/160
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0242 - val_loss: 0.0287
# Epoch 42/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0243 - val_loss: 0.0285
# Epoch 43/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0241 - val_loss: 0.0292
# Epoch 44/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0242 - val_loss: 0.0322
# Epoch 45/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0247 - val_loss: 0.0283
# Epoch 46/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0243 - val_loss: 0.0282
# Epoch 47/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0240 - val_loss: 0.0286
# Epoch 48/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0241 - val_loss: 0.0282
# Epoch 49/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0239 - val_loss: 0.0294
# Epoch 50/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0231 - val_loss: 0.0280
# Epoch 51/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0229 - val_loss: 0.0280
# Epoch 52/160
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0223 - val_loss: 0.0282
# Epoch 53/160
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0230 - val_loss: 0.0281
# Epoch 54/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0228 - val_loss: 0.0284
# Epoch 55/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0230 - val_loss: 0.0293
# Epoch 56/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0228 - val_loss: 0.0286
# Epoch 57/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0228 - val_loss: 0.0300
# Epoch 58/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0237 - val_loss: 0.0280
# Epoch 59/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0232 - val_loss: 0.0280
# Epoch 60/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0228 - val_loss: 0.0281
# Epoch 61/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0223 - val_loss: 0.0281
# Epoch 62/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0221 - val_loss: 0.0290
# Epoch 63/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0222 - val_loss: 0.0279
# Epoch 64/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0222 - val_loss: 0.0276
# Epoch 65/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0219 - val_loss: 0.0282
# Epoch 66/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0227 - val_loss: 0.0295
# Epoch 67/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0223 - val_loss: 0.0288
# Epoch 68/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0224 - val_loss: 0.0288
# Epoch 69/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0223 - val_loss: 0.0276
# Epoch 70/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0219 - val_loss: 0.0291
# Epoch 71/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0218 - val_loss: 0.0278
# Epoch 72/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0216 - val_loss: 0.0283
# Epoch 73/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0219 - val_loss: 0.0278
# Epoch 74/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0218 - val_loss: 0.0274
# Epoch 75/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0226 - val_loss: 0.0274
# Epoch 76/160
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0214 - val_loss: 0.0274
# Epoch 77/160
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0217 - val_loss: 0.0274
# Epoch 78/160
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0217 - val_loss: 0.0276
# Epoch 79/160
# 13/13 [==============================] - 0s 26ms/step - loss: 0.0224 - val_loss: 0.0292
# Epoch 80/160
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0217 - val_loss: 0.0290
# Epoch 81/160
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0216 - val_loss: 0.0279
# Epoch 82/160
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0216 - val_loss: 0.0274
# Epoch 83/160
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0211 - val_loss: 0.0278
# Epoch 84/160
# 13/13 [==============================] - 0s 26ms/step - loss: 0.0207 - val_loss: 0.0273
# Epoch 85/160
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0214 - val_loss: 0.0273
# Epoch 86/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0214 - val_loss: 0.0274
# Epoch 87/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0208 - val_loss: 0.0276
# Epoch 88/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0210 - val_loss: 0.0274
# Epoch 89/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0201 - val_loss: 0.0282
# Epoch 90/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0206 - val_loss: 0.0272
# Epoch 91/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0209 - val_loss: 0.0275
# Epoch 92/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0207 - val_loss: 0.0271
# Epoch 93/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0207 - val_loss: 0.0274
# Epoch 94/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0208 - val_loss: 0.0275
# Epoch 95/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0207 - val_loss: 0.0272
# Epoch 96/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0206 - val_loss: 0.0270
# Epoch 97/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0205 - val_loss: 0.0272
# Epoch 98/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0206 - val_loss: 0.0274
# Epoch 99/160
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0209 - val_loss: 0.0270
# Epoch 100/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0208 - val_loss: 0.0284
# Epoch 101/160
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0210 - val_loss: 0.0271
# Epoch 102/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0204 - val_loss: 0.0272
# Epoch 103/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0202 - val_loss: 0.0269
# Epoch 104/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0204 - val_loss: 0.0269
# Epoch 105/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0214 - val_loss: 0.0269
# Epoch 106/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0203 - val_loss: 0.0269
# Epoch 107/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0202 - val_loss: 0.0272
# Epoch 108/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0197 - val_loss: 0.0272
# Epoch 109/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0203 - val_loss: 0.0270
# Epoch 110/160
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0199 - val_loss: 0.0277
# Epoch 111/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0201 - val_loss: 0.0268
# Epoch 112/160
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0198 - val_loss: 0.0270
# Epoch 113/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0197 - val_loss: 0.0269
# Epoch 114/160
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0195 - val_loss: 0.0276
# Epoch 115/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0203 - val_loss: 0.0268
# Epoch 116/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0195 - val_loss: 0.0273
# Epoch 117/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0203 - val_loss: 0.0275
# Epoch 118/160
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0200 - val_loss: 0.0268
# Epoch 119/160
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0203 - val_loss: 0.0271
# Epoch 120/160
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0202 - val_loss: 0.0271
# Epoch 121/160
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0198 - val_loss: 0.0280
# Epoch 122/160
# 13/13 [==============================] - 0s 26ms/step - loss: 0.0207 - val_loss: 0.0284
# Epoch 123/160
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0199 - val_loss: 0.0284
# Epoch 124/160
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0197 - val_loss: 0.0280
# Epoch 125/160
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0201 - val_loss: 0.0275
# Epoch 126/160
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0197 - val_loss: 0.0267
# Epoch 127/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0194 - val_loss: 0.0266
# Epoch 128/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0191 - val_loss: 0.0286
# Epoch 129/160
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0195 - val_loss: 0.0269
# Epoch 130/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0195 - val_loss: 0.0269
# Epoch 131/160
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0205 - val_loss: 0.0269
# Epoch 132/160
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0193 - val_loss: 0.0291
# Epoch 133/160
# 13/13 [==============================] - 1s 40ms/step - loss: 0.0194 - val_loss: 0.0271
# Epoch 134/160
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0198 - val_loss: 0.0277
# Epoch 135/160
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0195 - val_loss: 0.0267
# Epoch 136/160
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0191 - val_loss: 0.0273
# Epoch 137/160
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0194 - val_loss: 0.0278
# Epoch 138/160
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0191 - val_loss: 0.0267
# Epoch 139/160
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0191 - val_loss: 0.0266
# Epoch 140/160
# 13/13 [==============================] - 0s 26ms/step - loss: 0.0199 - val_loss: 0.0267
# Epoch 141/160
# 13/13 [==============================] - 0s 31ms/step - loss: 0.0199 - val_loss: 0.0265
# Epoch 142/160
# 13/13 [==============================] - 0s 31ms/step - loss: 0.0196 - val_loss: 0.0266
# Epoch 143/160
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0191 - val_loss: 0.0265
# Epoch 144/160
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0193 - val_loss: 0.0266
# Epoch 145/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0196 - val_loss: 0.0266
# Epoch 146/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0192 - val_loss: 0.0270
# Epoch 147/160
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0197 - val_loss: 0.0274
# Epoch 148/160
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0194 - val_loss: 0.0265
# Epoch 149/160
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0190 - val_loss: 0.0270
# Epoch 150/160
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0185 - val_loss: 0.0265
# Epoch 151/160
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0184 - val_loss: 0.0266
# Epoch 152/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0184 - val_loss: 0.0265
# Epoch 153/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0193 - val_loss: 0.0265
# Epoch 154/160
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0193 - val_loss: 0.0268
# Epoch 155/160
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0191 - val_loss: 0.0266
# Epoch 156/160
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0190 - val_loss: 0.0266
# Epoch 157/160
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0191 - val_loss: 0.0282
# Epoch 158/160
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0191 - val_loss: 0.0266
# Epoch 159/160
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0190 - val_loss: 0.0266
# Epoch 160/160
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0184 - val_loss: 0.0264

# %%
# Gráfica de la pérdida para verificar que no exista overfitting ni underfitting
loss=history.history["loss"]
val_loss=history.history["val_loss"]
epochs=np.arange(1, 161)

plt.figure(figsize=(12, 6))
sns.lineplot(x=epochs, y=loss, color="blue", label="Entrenamiento")
sns.lineplot(x=epochs, y=val_loss, color="#FF6600", label="Evaluación")
plt.ylabel("Error")
plt.xlabel("Iteración")
plt.title("Evolución de la Pérdida del Modelo a través de las Iteraciones");

# %% [markdown]
# Del gráfico se visualiza que no se presenta overfitting, dado que a medida que la pérdida en el conjunto de entrenamiento disminuye, también lo hace en el conjunto de evaluación. Además, no se evidencia underfitting, ya que en cada iteración el valor de pérdida cada vez tiende más a 0 en ambos conjuntos, lo que indica un rendimiento excelente.

# %% [markdown]
# #### **Evaluación del Modelo**

# %%
rmse_train=model.evaluate(x=x_train, y=y_train, verbose=0)
rmse_test=model.evaluate(x=x_test, y=y_test, verbose=0)

print(f"RMSE train:\t {rmse_train}")
print(f"RMSE test:\t {rmse_test}")
# Out:
# RMSE train:	 0.012661034241318703
# RMSE test:	 0.024720026180148125

# %% [markdown]
# **El rendimiento del modelo es excelente, ya que el RMSE del set de entrenamiento es de 0.012661 y del set de evaluación es de 0.02472, valores muy cercanos a 0.**

# %%
# Creación de una función para las predicciones
def predictions(x_test, model, mms):
  y_pred=model.predict(x_test, verbose=0)
  y_pred=mms.inverse_transform(y_pred)
  return y_pred.squeeze()

# %%
# Hallando las predicciones de los Highs máximos
y_pred=predictions(x_test, model, mms)

print(y_pred.shape)
print(y_pred)
# Out:
# (530, 7)
# [[230.0289  229.3493  229.8514  ... 231.37755 230.29895 230.68947]
#  [229.09319 228.43486 228.97188 ... 230.50868 229.44139 229.84868]
#  [233.076   232.40253 232.92636 ... 234.44559 233.32744 233.71364]
#  ...
#  [309.01532 308.1276  308.68866 ... 310.6041  308.9413  309.6121 ]
#  [310.2185  309.3483  309.87708 ... 311.82593 310.09744 310.8195 ]
#  [310.41895 309.56412 310.08688 ... 312.05676 310.29672 311.07407]]

# %%
# Gráfica del RMSE en los 7 días predichos del set de testeo
y_test2=mms.inverse_transform(y_test.squeeze())
rmse=(((y_test2-y_pred)**2).mean(axis=0))**0.5
sns.scatterplot(x=np.linspace(1,7,7), y=rmse, color="blue")
plt.xlabel("High predicho (Día)")
plt.ylabel("RMSE (USD)")
plt.grid();

# %%
print("RMSE (USD) mínimo: ", round(rmse.min(),2))
print("RMSE (USD) máximo: ", round(rmse.max(),2))
# Out:
# RMSE (USD) mínimo:  4.85
# RMSE (USD) máximo:  12.49

# %%
print("Promedio de RMSE (USD): ", mean_squared_error(y_test2, y_pred, squared=False))
# Out:
# Promedio de RMSE (USD):  9.244146651060136

# %%
print("Promedio del Coeficiente de Determinación (R2): ", r2_score(y_test2, y_pred))
# Out:
# Promedio del Coeficiente de Determinación (R2):  0.9763267132137117

# %% [markdown]
# #### **CONCLUSIÓN:** A medida que se amplía el horizonte de predicción, se aprecia un incremento en el error. Utilizando la métrica RMSE, se observa que el error mínimo se registra en el día 1, alcanzando $4.85, mientras que el error máximo se presenta en el día 7, con un valor de $12.49. En términos generales, el RMSE promedio para los 7 días es de $9.24, con un coeficiente de determinación (R2) de 0.97!, indicando un ajuste sólido del modelo a los datos. Esto significa que, en promedio, las predicciones del modelo se desvían en solo $9.24 de los valores reales de las acciones máximas de Meta, respaldado por un R2 cercano al 100%, lo que refuerza la excelencia del modelo en su capacidad predictiva.

# %%
# Gráfica de las Acciones Reales y Predichas (Día 1)
df_meta=df[df.id_company=="META"].reset_index(drop=True)
day=1
start_index=df_meta.shape[0]-y_test.shape[0]-output_len+day
end_index=-output_len+day # Si es el último día no se considera

plt.figure(figsize=(12,6))
sns.lineplot(x=df_meta.iloc[start_index:end_index].Date, y=df_meta.iloc[start_index:end_index].High, color="blue", label="Valor Real")
sns.lineplot(x=df_meta.iloc[start_index:end_index].Date, y=y_pred[:, day-1], color="red", label="Valor Predicho")
plt.ylabel("Valor de la Acción más Alta (USD)")
plt.xlabel("Fecha")
plt.title(f"Valor de las Acciones más Altas de Meta a través del Tiempo (Día {day})");

# %% [markdown]
# **Las predicciones son casi perfectas a simple vista, pues según el gráfico del RMSE solo difieren en promedio 4.85 USD**

# %%
# Gráfica de las Acciones Reales y Predichas (Día 7)
df_meta=df[df.id_company=="META"].reset_index(drop=True)
day=7
start_index=df_meta.shape[0]-y_test.shape[0]-output_len+day

plt.figure(figsize=(12,6))
sns.lineplot(x=df_meta.iloc[start_index:].Date, y=df_meta.iloc[start_index:].High, color="blue", label="Valor Real")
sns.lineplot(x=df_meta.iloc[start_index:].Date, y=y_pred[:, day-1], color="red", label="Valor Predicho")
plt.ylabel("Valor de la Acción más Alta (USD)")
plt.xlabel("Fecha")
plt.title(f"Valor de las Acciones más Altas de Meta a través del Tiempo (Día {day})");

# %% [markdown]
# **Las predicciones difieren un poco más, pues según el gráfico del RMSE difieren en promedio en 12.49 USD**

# %% [markdown]
# #### **Guardando el modelo entrenado en un archivo en formato nativo de Keras**

# %%
model.save("model_meta.keras")
